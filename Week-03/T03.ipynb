# %%
# !pip install qiskit qiskit-aer -q

# %%
import random
import numpy as np

from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit_aer import AerSimulator
# Out:
# /var/folders/yp/078pyxw11mq6g7sd_2ty18z80000gn/T/ipykernel_27120/2087795024.py:4: DeprecationWarning: Using Qiskit with Python 3.9 is deprecated as of the 2.1.0 release. Support for running Qiskit with Python 3.9 will be removed in the 2.3.0 release, which coincides with when Python 3.9 goes end of life.
#   from qiskit import QuantumCircuit

# %%
def show_state(circuit, title):
    state = Statevector.from_instruction(circuit)
    print("="*60)
    print(title)
    print(circuit.draw())
    print("\nStatevector:")
    print(state)
    print("="*60)
    return state

# %%
gate_list = ['x','y','z','h']

random_gates = [random.choice(gate_list) for _ in range(5)]

print("Random Gates Selected:\n")
print(random_gates)
# Out:
# Random Gates Selected:
#
# ['h', 'z', 'z', 'z', 'x']

# %%
qc_random = QuantumCircuit(1)

for gate in random_gates:

    if gate == 'x':
        qc_random.x(0)

    elif gate == 'y':
        qc_random.y(0)

    elif gate == 'z':
        qc_random.z(0)

    elif gate == 'h':
        qc_random.h(0)

state_random = show_state(qc_random, "Random Five-Gate Circuit")
# Out:
# ============================================================
# Random Five-Gate Circuit
#    ┌───┐┌───┐┌───┐┌───┐┌───┐
# q: ┤ H ├┤ Z ├┤ Z ├┤ Z ├┤ X ├
#    └───┘└───┘└───┘└───┘└───┘
#
# Statevector:
# Statevector([-0.70710678+0.j,  0.70710678+0.j],
#             dims=(2,))
# ============================================================

# %%
print("Analytical Final Statevector:\n")
print(state_random.data)
# Out:
# Analytical Final Statevector:
#
# [-0.70710678+0.j  0.70710678+0.j]

# %%
simulator = AerSimulator(method="statevector")

result = simulator.run(qc_random).result()

state_sim = Statevector.from_instruction(qc_random)

print("Simulation Statevector:\n")
print(state_sim.data)

print("\nVerification:")
print(np.allclose(state_random.data, state_sim.data))
# Out:
# Simulation Statevector:
#
# [-0.70710678+0.j  0.70710678+0.j]
#
# Verification:
# True
